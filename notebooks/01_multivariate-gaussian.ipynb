# %% [markdown]
# # Sampling from a multivariate Gaussian using a GAN
# In this example we'll try to learn a generator sampling from a simple $N$-dimensional multivariate Gaussian.

# %%
import os
import torch

import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt

os.chdir("/home/thomas/Backup/Algorithmen/GAN-pytorch")
from vegans.GAN import WassersteinGAN
from vegans.utils.utils import plot_losses

# %%
z_dim = 32  # noise vector size
N = 20  # size of sampled vectors

# %% [markdown]
# ## Prepare the "training" dataset
# First, we define a $NxN$ covariance matrix, and plot it:

# %%
cov_mat = np.zeros(shape=(N, N))
cov_mat[0:10, 0:10] = 0.8
np.fill_diagonal(cov_mat, 1.)

plt.imshow(cov_mat)
plt.title('Data generating process covariance matrix')
plt.colorbar();

# %% [markdown]
# Our goal will be to train a generator network in a GAN setting, which can sample from a distribution with a similar covariance matrix.
#
# For reference, here's the sample covariance matrix, obtained when sampling from this distribution:

# %%
X_train = np.random.multivariate_normal(mean=np.array([0. for _ in range(N)]), cov=cov_mat, size=10000)

# re-cover matrix
cov_mat_recovered = np.cov(X_train.T)

plt.imshow(cov_mat_recovered)
plt.title('Sample cov matrix from multivariate Gaussian');
plt.colorbar();

# %% [markdown]
# Let's now have a look at the distribution of our (flattened) training set:

# %%
plt.hist(X_train.flatten(), bins=50)
plt.title('Histogram of (flattened) training set samples');

# %% [markdown]
# ## Define our Generator and Critic Networks
# Here we'll define some very simple nets.

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.hidden_part = nn.Sequential(
            nn.Linear(z_dim, 32),
            nn.LeakyReLU(0.1),
        )
        self.output = nn.Linear(32, 20)

    def forward(self, x):
        x = self.hidden_part(x)
        x = self.output(x)
        return x

class Critic(nn.Module):
    def __init__(self):
        super(Critic, self).__init__()
        self.hidden_part = nn.Sequential(
            nn.Linear(N, 10),
            nn.LeakyReLU(0.1),
            nn.Linear(10, 1)
        )
        self.output = nn.Identity()

    def forward(self, x):
        x = self.hidden_part(x)
        x = self.output(x)
        return x
    
critic = Critic()
generator = Generator()

# %% [markdown]
# We didn't train our generator yet, so it's just generating noise. What does the sample covariance matrix look like?

# %%
def plot_generator_cov(generator, n=10000):
    """ Try the generator on a noise mini-batch and compute sample covariance matrix
    """
    z = torch.from_numpy(np.random.randn(n, z_dim)).float()
    samples = generator(z)
    cov_mat_est = np.cov(samples.detach().numpy().T)
    plt.imshow(cov_mat_est)
    plt.title('sample covariance matrix from generator network');
    plt.colorbar();
    
plot_generator_cov(generator)

# %% [markdown]
# ## Time for training!
# We'll use [WGAN-GP](https://arxiv.org/abs/1704.00028). Here we'll define our own optimizers for the generator and the critic, in order to use a slightly lower learning rate than the default one.
#
# We'll train for 50 epochs.
#
# We set `folder=None` so that no folder is created where all results would be stored. Otherwise we could give a path like `folder="TrainedModels/GAN"`. All results (summary, images, loss functions, tensorboard information, models) would be saved in that folder. You can control what should be saved in the `fit` method. This folder will never overwrite an existing folder. If the path already exists a new path of the form `folder=path_{TimeStamp}` is created.

# %%
optimizer = {
    "Generator": torch.optim.Adam,
    "Adversariat": torch.optim.Adam
}
optimizer_kwargs = {
    "Generator": {"lr": 0.0001, "betas": (0.5, 0.999)},
    "Adversariat": {"lr": 0.0001, "betas": (0.5, 0.999)},
}

gan = WassersteinGAN(
    generator, critic, z_dim=z_dim, x_dim=N, 
    optim=optimizer, optim_kwargs=optimizer_kwargs, device="cpu", folder=None
)

# %% [markdown]
# The training happens in the next cell. You can interrupt it at any time without loosing the results.

# %%
gan.fit(X_train, epochs=25, print_every="1e", enable_tensorboard=False)
# Out:
# ------------------------------------------------------------
# EPOCH: 1
# ------------------------------------------------------------
# /home/thomas/miniconda3/envs/pytorch38/lib/python3.8/site-packages/torch/autograd/__init__.py:145: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at  /opt/conda/conda-bld/pytorch_1614378062065/work/c10/cuda/CUDAFunctions.cpp:109.)
#   Variable._execution_engine.run_backward(
# Step: 313 / 7825 (Epoch: 1 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.010485013015568256
# Adversariat: -0.0007375297136604786
# Adversariat_fake: -0.010485013015568256
# Adversariat_real: 0.0090099535882473
# RealFakeRatio: -0.8593173623085022
#
#
# Time left: ~0.21 minutes (Steps remaining: 7512).
#
#
# ------------------------------------------------------------
# EPOCH: 2
# ------------------------------------------------------------
# Step: 626 / 7825 (Epoch: 2 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.010226517915725708
# Adversariat: -0.0008847266435623169
# Adversariat_fake: -0.010226517915725708
# Adversariat_real: 0.008457064628601074
# RealFakeRatio: -0.8269740343093872
#
#
# Time left: ~0.212 minutes (Steps remaining: 7199).
#
#
# ------------------------------------------------------------
# EPOCH: 3
# ------------------------------------------------------------
# Step: 939 / 7825 (Epoch: 3 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.01012702751904726
# Adversariat: -0.0008373339660465717
# Adversariat_fake: -0.01012702751904726
# Adversariat_real: 0.008452359586954117
# RealFakeRatio: -0.8346338272094727
#
#
# Time left: ~0.197 minutes (Steps remaining: 6886).
#
#
# ------------------------------------------------------------
# EPOCH: 4
# ------------------------------------------------------------
# Step: 1252 / 7825 (Epoch: 4 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009858447127044201
# Adversariat: -0.0006303684785962105
# Adversariat_fake: -0.009858447127044201
# Adversariat_real: 0.00859771016985178
# RealFakeRatio: -0.8721160888671875
#
#
# Time left: ~0.186 minutes (Steps remaining: 6573).
#
#
# ------------------------------------------------------------
# EPOCH: 5
# ------------------------------------------------------------
# Step: 1565 / 7825 (Epoch: 5 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.00981796532869339
# Adversariat: -0.0004702182486653328
# Adversariat_fake: -0.00981796532869339
# Adversariat_real: 0.008877528831362724
# RealFakeRatio: -0.9042127132415771
#
#
# Time left: ~0.179 minutes (Steps remaining: 6260).
#
#
# ------------------------------------------------------------
# EPOCH: 6
# ------------------------------------------------------------
# Step: 1878 / 7825 (Epoch: 6 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.00999342743307352
# Adversariat: -0.0003364770673215389
# Adversariat_fake: -0.00999342743307352
# Adversariat_real: 0.009320473298430443
# RealFakeRatio: -0.9326603412628174
#
#
# Time left: ~0.168 minutes (Steps remaining: 5947).
#
#
# ------------------------------------------------------------
# EPOCH: 7
# ------------------------------------------------------------
# Step: 2191 / 7825 (Epoch: 7 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009041567333042622
# Adversariat: -0.00014645513147115707
# Adversariat_fake: -0.009041567333042622
# Adversariat_real: 0.008748657070100307
# RealFakeRatio: -0.9676040410995483
#
#
# Time left: ~0.158 minutes (Steps remaining: 5634).
#
#
# ------------------------------------------------------------
# EPOCH: 8
# ------------------------------------------------------------
# Step: 2504 / 7825 (Epoch: 8 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.00850489642471075
# Adversariat: 0.00010098516941070557
# Adversariat_fake: -0.00850489642471075
# Adversariat_real: 0.008706866763532162
# RealFakeRatio: -1.0237475633621216
#
#
# Time left: ~0.153 minutes (Steps remaining: 5321).
#
#
# ------------------------------------------------------------
# EPOCH: 9
# ------------------------------------------------------------
# Step: 2817 / 7825 (Epoch: 9 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009592586196959019
# Adversariat: -6.088335067033768e-05
# Adversariat_fake: -0.009592586196959019
# Adversariat_real: 0.009470819495618343
# RealFakeRatio: -0.9873061776161194
#
#
# Time left: ~0.145 minutes (Steps remaining: 5008).
#
#
# ------------------------------------------------------------
# EPOCH: 10
# ------------------------------------------------------------
# Step: 3130 / 7825 (Epoch: 10 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009704392403364182
# Adversariat: -0.0002826983109116554
# Adversariat_fake: -0.009704392403364182
# Adversariat_real: 0.00913899578154087
# RealFakeRatio: -0.9417380690574646
#
#
# Time left: ~0.138 minutes (Steps remaining: 4695).
#
#
# ------------------------------------------------------------
# EPOCH: 11
# ------------------------------------------------------------
# Step: 3443 / 7825 (Epoch: 11 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009860015474259853
# Adversariat: -0.0003214385360479355
# Adversariat_fake: -0.009860015474259853
# Adversariat_real: 0.009217138402163982
# RealFakeRatio: -0.9347996115684509
#
#
# Time left: ~0.128 minutes (Steps remaining: 4382).
#
#
# ------------------------------------------------------------
# EPOCH: 12
# ------------------------------------------------------------
# Step: 3756 / 7825 (Epoch: 12 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009989527985453606
# Adversariat: -0.0003561452031135559
# Adversariat_fake: -0.009989527985453606
# Adversariat_real: 0.009277237579226494
# RealFakeRatio: -0.9286962747573853
#
#
# Time left: ~0.119 minutes (Steps remaining: 4069).
#
#
# ------------------------------------------------------------
# EPOCH: 13
# ------------------------------------------------------------
# Step: 4069 / 7825 (Epoch: 13 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009968467056751251
# Adversariat: -0.0003106147050857544
# Adversariat_fake: -0.009968467056751251
# Adversariat_real: 0.009347237646579742
# RealFakeRatio: -0.9376805424690247
#
#
# Time left: ~0.109 minutes (Steps remaining: 3756).
#
#
# ------------------------------------------------------------
# EPOCH: 14
# ------------------------------------------------------------
# Step: 4382 / 7825 (Epoch: 14 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009856457822024822
# Adversariat: -0.0002785208635032177
# Adversariat_fake: -0.009856457822024822
# Adversariat_real: 0.009299416095018387
# RealFakeRatio: -0.9434846043586731
#
#
# Time left: ~0.1 minutes (Steps remaining: 3443).
#
#
# ------------------------------------------------------------
# EPOCH: 15
# ------------------------------------------------------------
# Step: 4695 / 7825 (Epoch: 15 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009926247410476208
# Adversariat: -0.00027126772329211235
# Adversariat_fake: -0.009926247410476208
# Adversariat_real: 0.009383711963891983
# RealFakeRatio: -0.9453433752059937
#
#
# Time left: ~0.092 minutes (Steps remaining: 3130).
#
#
# ------------------------------------------------------------
# EPOCH: 16
# ------------------------------------------------------------
# Step: 5008 / 7825 (Epoch: 16 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009856057353317738
# Adversariat: -0.00032378314062952995
# Adversariat_fake: -0.009856057353317738
# Adversariat_real: 0.009208491072058678
# RealFakeRatio: -0.9342976212501526
#
#
# Time left: ~0.083 minutes (Steps remaining: 2817).
#
#
# ------------------------------------------------------------
# EPOCH: 17
# ------------------------------------------------------------
# Step: 5321 / 7825 (Epoch: 17 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009782888926565647
# Adversariat: -0.00029015541076660156
# Adversariat_fake: -0.009782888926565647
# Adversariat_real: 0.009202578105032444
# RealFakeRatio: -0.9406810402870178
#
#
# Time left: ~0.074 minutes (Steps remaining: 2504).
#
#
# ------------------------------------------------------------
# EPOCH: 18
# ------------------------------------------------------------
# Step: 5634 / 7825 (Epoch: 18 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009871960617601871
# Adversariat: -0.0003443998284637928
# Adversariat_fake: -0.009871960617601871
# Adversariat_real: 0.009183160960674286
# RealFakeRatio: -0.9302266836166382
#
#
# Time left: ~0.065 minutes (Steps remaining: 2191).
#
#
# ------------------------------------------------------------
# EPOCH: 19
# ------------------------------------------------------------
# Step: 5947 / 7825 (Epoch: 19 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.00977539736777544
# Adversariat: -0.0002581002190709114
# Adversariat_fake: -0.00977539736777544
# Adversariat_real: 0.009259196929633617
# RealFakeRatio: -0.9471939206123352
#
#
# Time left: ~0.056 minutes (Steps remaining: 1878).
#
#
# ------------------------------------------------------------
# EPOCH: 20
# ------------------------------------------------------------
# Step: 6260 / 7825 (Epoch: 20 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009854242205619812
# Adversariat: -0.00030714087188243866
# Adversariat_fake: -0.009854242205619812
# Adversariat_real: 0.009239960461854935
# RealFakeRatio: -0.937663197517395
#
#
# Time left: ~0.047 minutes (Steps remaining: 1565).
#
#
# ------------------------------------------------------------
# EPOCH: 21
# ------------------------------------------------------------
# Step: 6573 / 7825 (Epoch: 21 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009806319139897823
# Adversariat: -0.0002797353081405163
# Adversariat_fake: -0.009806319139897823
# Adversariat_real: 0.00924684852361679
# RealFakeRatio: -0.9429479241371155
#
#
# Time left: ~0.038 minutes (Steps remaining: 1252).
#
#
# ------------------------------------------------------------
# EPOCH: 22
# ------------------------------------------------------------
# Step: 6886 / 7825 (Epoch: 22 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009675638750195503
# Adversariat: -0.00031518563628196716
# Adversariat_fake: -0.009675638750195503
# Adversariat_real: 0.009045267477631569
# RealFakeRatio: -0.9348496198654175
#
#
# Time left: ~0.028 minutes (Steps remaining: 939).
#
#
# ------------------------------------------------------------
# EPOCH: 23
# ------------------------------------------------------------
# Step: 7199 / 7825 (Epoch: 23 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009643429890275002
# Adversariat: -0.00021420978009700775
# Adversariat_fake: -0.009643429890275002
# Adversariat_real: 0.009215010330080986
# RealFakeRatio: -0.9555739164352417
#
#
# Time left: ~0.019 minutes (Steps remaining: 626).
#
#
# ------------------------------------------------------------
# EPOCH: 24
# ------------------------------------------------------------
# Step: 7512 / 7825 (Epoch: 24 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009574560448527336
# Adversariat: -0.00017083529382944107
# Adversariat_fake: -0.009574560448527336
# Adversariat_real: 0.009232889860868454
# RealFakeRatio: -0.9643147587776184
#
#
# Time left: ~0.009 minutes (Steps remaining: 313).
#
#
# ------------------------------------------------------------
# EPOCH: 25
# ------------------------------------------------------------
# Step: 7825 / 7825 (Epoch: 25 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009598826989531517
# Adversariat: -0.00016109691932797432
# Adversariat_fake: -0.009598826989531517
# Adversariat_real: 0.009276633150875568
# RealFakeRatio: -0.9664340615272522
#
#
# Time left: ~0.0 minutes (Steps remaining: 0).

# %% [markdown]
# ## Inspection of results
# By calling `get_training_results()` on any GAN object, you can get a list of samples (generated out of a fixed noise vector), as well as the lists of losses of the generator and discriminator:

# %%
samples, losses = gan.get_training_results()

# %% [markdown]
# First, let's check what's the distribution of (flattened) samples during the last iteration:

# %%
plt.hist(samples.flatten(), bins=50);

# %% [markdown]
# And now let's look at the losses of the generator and critic during training - we can just call `vegans.utils.plot_losses()`:

# %%
fig, axs = plot_losses(losses)

# %% [markdown]
# And the sample covariance matrix we obtain we drawing samples from our newly-trained generator:

# %%
plot_generator_cov(generator)

# %% [markdown]
# It looks very similar to the original matrix.
