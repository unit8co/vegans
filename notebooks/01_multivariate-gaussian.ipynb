# %% [markdown]
# # Sampling from a multivariate Gaussian using a GAN
# In this example we'll try to learn a generator sampling from a simple $N$-dimensional multivariate Gaussian.

# %%
import os
import torch

import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt

os.chdir("/home/thomas/Backup/Algorithmen/vegans")
from vegans.GAN import WassersteinGAN
from vegans.utils.utils import plot_losses

# %%
z_dim = 32  # noise vector size
N = 20  # size of sampled vectors

# %% [markdown]
# ## Prepare the "training" dataset
# First, we define a $NxN$ covariance matrix, and plot it:

# %%
cov_mat = np.zeros(shape=(N, N))
cov_mat[0:10, 0:10] = 0.8
np.fill_diagonal(cov_mat, 1.)

plt.imshow(cov_mat)
plt.title('Data generating process covariance matrix')
plt.colorbar();

# %% [markdown]
# Our goal will be to train a generator network in a GAN setting, which can sample from a distribution with a similar covariance matrix.
#
# For reference, here's the sample covariance matrix, obtained when sampling from this distribution:

# %%
X_train = np.random.multivariate_normal(mean=np.array([0. for _ in range(N)]), cov=cov_mat, size=10000)

# re-cover matrix
cov_mat_recovered = np.cov(X_train.T)

plt.imshow(cov_mat_recovered)
plt.title('Sample cov matrix from multivariate Gaussian');
plt.colorbar();

# %% [markdown]
# Let's now have a look at the distribution of our (flattened) training set:

# %%
plt.hist(X_train.flatten(), bins=50)
plt.title('Histogram of (flattened) training set samples');

# %% [markdown]
# ## Define our Generator and Critic Networks
# Here we'll define some very simple nets.

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.hidden_part = nn.Sequential(
            nn.Linear(z_dim, 32),
            nn.LeakyReLU(0.1),
        )
        self.output = nn.Linear(32, 20)

    def forward(self, x):
        x = self.hidden_part(x)
        x = self.output(x)
        return x

class Critic(nn.Module):
    def __init__(self):
        super(Critic, self).__init__()
        self.hidden_part = nn.Sequential(
            nn.Linear(N, 10),
            nn.LeakyReLU(0.1),
            nn.Linear(10, 1)
        )
        self.output = nn.Identity()

    def forward(self, x):
        x = self.hidden_part(x)
        x = self.output(x)
        return x
    
critic = Critic()
generator = Generator()

# %% [markdown]
# We didn't train our generator yet, so it's just generating noise. What does the sample covariance matrix look like?

# %%
def plot_generator_cov(generator, n=10000):
    """ Try the generator on a noise mini-batch and compute sample covariance matrix
    """
    z = torch.from_numpy(np.random.randn(n, z_dim)).float()
    samples = generator(z)
    cov_mat_est = np.cov(samples.detach().numpy().T)
    plt.imshow(cov_mat_est)
    plt.title('sample covariance matrix from generator network');
    plt.colorbar();
    
plot_generator_cov(generator)

# %% [markdown]
# ## Time for training!
# We'll use [WGAN-GP](https://arxiv.org/abs/1704.00028). Here we'll define our own optimizers for the generator and the critic, in order to use a slightly lower learning rate than the default one.
#
# We'll train for 50 epochs.
#
# We set `folder=None` so that no folder is created where all results would be stored. Otherwise we could give a path like `folder="TrainedModels/GAN"`. All results (summary, images, loss functions, tensorboard information, models) would be saved in that folder. You can control what should be saved in the `fit` method. This folder will never overwrite an existing folder. If the path already exists a new path of the form `folder=path_{TimeStamp}` is created.

# %%
optimizer = {
    "Generator": torch.optim.Adam,
    "Adversariat": torch.optim.Adam
}
optimizer_kwargs = {
    "Generator": {"lr": 0.0001, "betas": (0.5, 0.999)},
    "Adversariat": {"lr": 0.0001, "betas": (0.5, 0.999)},
}

gan = WassersteinGAN(
    generator, critic, z_dim=z_dim, x_dim=N, 
    optim=optimizer, optim_kwargs=optimizer_kwargs, device="cpu", folder=None
)

# %% [markdown]
# The training happens in the next cell. You can interrupt it at any time without loosing the results.

# %%
gan.fit(X_train, epochs=25, print_every="1e", enable_tensorboard=False)
# Out:
# ------------------------------------------------------------
# EPOCH: 1
# ------------------------------------------------------------
# /home/thomas/miniconda3/envs/pytorch38/lib/python3.8/site-packages/torch/autograd/__init__.py:145: UserWarning: CUDA initialization: Unexpected error from cudaGetDeviceCount(). Did you run some cuda functions before calling NumCudaDevices() that might have already set an error? Error 804: forward compatibility was attempted on non supported HW (Triggered internally at  /opt/conda/conda-bld/pytorch_1614378062065/work/c10/cuda/CUDAFunctions.cpp:109.)
#   Variable._execution_engine.run_backward(
# Step: 313 / 7825 (Epoch: 1 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.011138823814690113
# Adversariat: -0.001678995555266738
# Adversariat_fake: -0.011138823814690113
# Adversariat_real: 0.007780832704156637
# RealFakeRatio: -0.6985327005386353
#
#
# Time left: ~0.639 minutes (Steps remaining: 7512).
#
#
# ------------------------------------------------------------
# EPOCH: 2
# ------------------------------------------------------------
# Step: 626 / 7825 (Epoch: 2 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.010764273814857006
# Adversariat: -0.0013706828467547894
# Adversariat_fake: -0.010764273814857006
# Adversariat_real: 0.008022908121347427
# RealFakeRatio: -0.7453274130821228
#
#
# Time left: ~0.599 minutes (Steps remaining: 7199).
#
#
# ------------------------------------------------------------
# EPOCH: 3
# ------------------------------------------------------------
# Step: 939 / 7825 (Epoch: 3 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.010547862388193607
# Adversariat: -0.0012522339820861816
# Adversariat_fake: -0.010547862388193607
# Adversariat_real: 0.008043394424021244
# RealFakeRatio: -0.762561559677124
#
#
# Time left: ~0.569 minutes (Steps remaining: 6886).
#
#
# ------------------------------------------------------------
# EPOCH: 4
# ------------------------------------------------------------
# Step: 1252 / 7825 (Epoch: 4 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.01031608134508133
# Adversariat: -0.0010203025303781033
# Adversariat_fake: -0.01031608134508133
# Adversariat_real: 0.008275476284325123
# RealFakeRatio: -0.8021918535232544
#
#
# Time left: ~0.543 minutes (Steps remaining: 6573).
#
#
# ------------------------------------------------------------
# EPOCH: 5
# ------------------------------------------------------------
# Step: 1565 / 7825 (Epoch: 5 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.010465322062373161
# Adversariat: -0.001111464574933052
# Adversariat_fake: -0.010465322062373161
# Adversariat_real: 0.008242392912507057
# RealFakeRatio: -0.7875909209251404
#
#
# Time left: ~0.519 minutes (Steps remaining: 6260).
#
#
# ------------------------------------------------------------
# EPOCH: 6
# ------------------------------------------------------------
# Step: 1878 / 7825 (Epoch: 6 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.010468089953064919
# Adversariat: -0.0009892047382891178
# Adversariat_fake: -0.010468089953064919
# Adversariat_real: 0.008489680476486683
# RealFakeRatio: -0.811005711555481
#
#
# Time left: ~0.492 minutes (Steps remaining: 5947).
#
#
# ------------------------------------------------------------
# EPOCH: 7
# ------------------------------------------------------------
# Step: 2191 / 7825 (Epoch: 7 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.010364238172769547
# Adversariat: -0.0009012026712298393
# Adversariat_fake: -0.010364238172769547
# Adversariat_real: 0.008561832830309868
# RealFakeRatio: -0.8260937929153442
#
#
# Time left: ~0.465 minutes (Steps remaining: 5634).
#
#
# ------------------------------------------------------------
# EPOCH: 8
# ------------------------------------------------------------
# Step: 2504 / 7825 (Epoch: 8 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.01027688104659319
# Adversariat: -0.0008909692987799644
# Adversariat_fake: -0.01027688104659319
# Adversariat_real: 0.00849494244903326
# RealFakeRatio: -0.8266070485115051
#
#
# Time left: ~0.44 minutes (Steps remaining: 5321).
#
#
# ------------------------------------------------------------
# EPOCH: 9
# ------------------------------------------------------------
# Step: 2817 / 7825 (Epoch: 9 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.010186213068664074
# Adversariat: -0.0007445891387760639
# Adversariat_fake: -0.010186213068664074
# Adversariat_real: 0.008697034791111946
# RealFakeRatio: -0.8538045287132263
#
#
# Time left: ~0.417 minutes (Steps remaining: 5008).
#
#
# ------------------------------------------------------------
# EPOCH: 10
# ------------------------------------------------------------
# Step: 3130 / 7825 (Epoch: 10 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.00968391727656126
# Adversariat: -0.0007588351145386696
# Adversariat_fake: -0.00968391727656126
# Adversariat_real: 0.008166247047483921
# RealFakeRatio: -0.8432793021202087
#
#
# Time left: ~0.392 minutes (Steps remaining: 4695).
#
#
# ------------------------------------------------------------
# EPOCH: 11
# ------------------------------------------------------------
# Step: 3443 / 7825 (Epoch: 11 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009169502183794975
# Adversariat: -0.000533662736415863
# Adversariat_fake: -0.009169502183794975
# Adversariat_real: 0.00810217671096325
# RealFakeRatio: -0.8836004734039307
#
#
# Time left: ~0.37 minutes (Steps remaining: 4382).
#
#
# ------------------------------------------------------------
# EPOCH: 12
# ------------------------------------------------------------
# Step: 3756 / 7825 (Epoch: 12 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.00969352200627327
# Adversariat: -0.0002880692481994629
# Adversariat_fake: -0.00969352200627327
# Adversariat_real: 0.009117383509874344
# RealFakeRatio: -0.9405645728111267
#
#
# Time left: ~0.343 minutes (Steps remaining: 4069).
#
#
# ------------------------------------------------------------
# EPOCH: 13
# ------------------------------------------------------------
# Step: 4069 / 7825 (Epoch: 13 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.010376916266977787
# Adversariat: -0.0003341245464980602
# Adversariat_fake: -0.010376916266977787
# Adversariat_real: 0.009708667173981667
# RealFakeRatio: -0.9356023669242859
#
#
# Time left: ~0.316 minutes (Steps remaining: 3756).
#
#
# ------------------------------------------------------------
# EPOCH: 14
# ------------------------------------------------------------
# Step: 4382 / 7825 (Epoch: 14 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.010387486778199673
# Adversariat: -0.0003058905713260174
# Adversariat_fake: -0.010387486778199673
# Adversariat_real: 0.009775705635547638
# RealFakeRatio: -0.9411040544509888
#
#
# Time left: ~0.289 minutes (Steps remaining: 3443).
#
#
# ------------------------------------------------------------
# EPOCH: 15
# ------------------------------------------------------------
# Step: 4695 / 7825 (Epoch: 15 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.010241622105240822
# Adversariat: -0.0002959691919386387
# Adversariat_fake: -0.010241622105240822
# Adversariat_real: 0.009649683721363544
# RealFakeRatio: -0.9422026872634888
#
#
# Time left: ~0.264 minutes (Steps remaining: 3130).
#
#
# ------------------------------------------------------------
# EPOCH: 16
# ------------------------------------------------------------
# Step: 5008 / 7825 (Epoch: 16 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.010258627124130726
# Adversariat: -0.000348671805113554
# Adversariat_fake: -0.010258627124130726
# Adversariat_real: 0.009561283513903618
# RealFakeRatio: -0.9320237040519714
#
#
# Time left: ~0.24 minutes (Steps remaining: 2817).
#
#
# ------------------------------------------------------------
# EPOCH: 17
# ------------------------------------------------------------
# Step: 5321 / 7825 (Epoch: 17 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.010166598483920097
# Adversariat: -0.00022449064999818802
# Adversariat_fake: -0.010166598483920097
# Adversariat_real: 0.009717617183923721
# RealFakeRatio: -0.955837607383728
#
#
# Time left: ~0.213 minutes (Steps remaining: 2504).
#
#
# ------------------------------------------------------------
# EPOCH: 18
# ------------------------------------------------------------
# Step: 5634 / 7825 (Epoch: 18 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.01031324453651905
# Adversariat: -0.00040262239053845406
# Adversariat_fake: -0.01031324453651905
# Adversariat_real: 0.009507999755442142
# RealFakeRatio: -0.9219213128089905
#
#
# Time left: ~0.186 minutes (Steps remaining: 2191).
#
#
# ------------------------------------------------------------
# EPOCH: 19
# ------------------------------------------------------------
# Step: 5947 / 7825 (Epoch: 19 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.010073840618133545
# Adversariat: -0.0003469381481409073
# Adversariat_fake: -0.010073840618133545
# Adversariat_real: 0.00937996432185173
# RealFakeRatio: -0.9311209917068481
#
#
# Time left: ~0.159 minutes (Steps remaining: 1878).
#
#
# ------------------------------------------------------------
# EPOCH: 20
# ------------------------------------------------------------
# Step: 6260 / 7825 (Epoch: 20 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.01033647358417511
# Adversariat: -0.0003457176499068737
# Adversariat_fake: -0.01033647358417511
# Adversariat_real: 0.009645038284361362
# RealFakeRatio: -0.9331072568893433
#
#
# Time left: ~0.133 minutes (Steps remaining: 1565).
#
#
# ------------------------------------------------------------
# EPOCH: 21
# ------------------------------------------------------------
# Step: 6573 / 7825 (Epoch: 21 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.010321032255887985
# Adversariat: -0.0003471742384135723
# Adversariat_fake: -0.010321032255887985
# Adversariat_real: 0.00962668377906084
# RealFakeRatio: -0.9327248930931091
#
#
# Time left: ~0.106 minutes (Steps remaining: 1252).
#
#
# ------------------------------------------------------------
# EPOCH: 22
# ------------------------------------------------------------
# Step: 6886 / 7825 (Epoch: 22 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.01009964570403099
# Adversariat: -0.00020203925669193268
# Adversariat_fake: -0.01009964570403099
# Adversariat_real: 0.009695567190647125
# RealFakeRatio: -0.9599907994270325
#
#
# Time left: ~0.08 minutes (Steps remaining: 939).
#
#
# ------------------------------------------------------------
# EPOCH: 23
# ------------------------------------------------------------
# Step: 7199 / 7825 (Epoch: 23 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009773176163434982
# Adversariat: -0.0003334004431962967
# Adversariat_fake: -0.009773176163434982
# Adversariat_real: 0.009106375277042389
# RealFakeRatio: -0.9317723512649536
#
#
# Time left: ~0.053 minutes (Steps remaining: 626).
#
#
# ------------------------------------------------------------
# EPOCH: 24
# ------------------------------------------------------------
# Step: 7512 / 7825 (Epoch: 24 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.00964831281453371
# Adversariat: -0.00039616506546735764
# Adversariat_fake: -0.00964831281453371
# Adversariat_real: 0.008855982683598995
# RealFakeRatio: -0.9178788661956787
#
#
# Time left: ~0.027 minutes (Steps remaining: 313).
#
#
# ------------------------------------------------------------
# EPOCH: 25
# ------------------------------------------------------------
# Step: 7825 / 7825 (Epoch: 25 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: 0.009730970486998558
# Adversariat: -0.00048803817480802536
# Adversariat_fake: -0.009730970486998558
# Adversariat_real: 0.008754894137382507
# RealFakeRatio: -0.8996938467025757
#
#
# Time left: ~0.0 minutes (Steps remaining: 0).

# %% [markdown]
# ## Inspection of results
# By calling `get_training_results()` on any GAN object, you can get a list of samples (generated out of a fixed noise vector), as well as the lists of losses of the generator and discriminator:

# %%
samples, losses = gan.get_training_results()

# %% [markdown]
# First, let's check what's the distribution of (flattened) samples during the last iteration:

# %%
plt.hist(samples.flatten(), bins=50);

# %% [markdown]
# And now let's look at the losses of the generator and critic during training - we can just call `vegans.utils.plot_losses()`:

# %%
fig, axs = plot_losses(losses)

# %% [markdown]
# And the sample covariance matrix we obtain we drawing samples from our newly-trained generator:

# %%
plot_generator_cov(generator)

# %% [markdown]
# It looks very similar to the original matrix.
