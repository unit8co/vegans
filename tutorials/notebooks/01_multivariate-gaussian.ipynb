# %% [markdown]
# # Sampling from a multivariate Gaussian using a GAN
# In this example we'll try to learn a generator sampling from a simple $N$-dimensional multivariate Gaussian.

# %%
import os
import torch

import numpy as np
import torch.nn as nn
import matplotlib.pyplot as plt

from vegans.GAN import WassersteinGAN
from vegans.utils.utils import plot_losses

# %%
z_dim = 32  # noise vector size
N = 20  # size of sampled vectors

# %% [markdown]
# ## Prepare the "training" dataset
# First, we define a $NxN$ covariance matrix, and plot it:

# %%
cov_mat = np.zeros(shape=(N, N))
cov_mat[0:10, 0:10] = 0.8
np.fill_diagonal(cov_mat, 1.)

plt.imshow(cov_mat)
plt.title('Data generating process covariance matrix')
plt.colorbar();

# %% [markdown]
# Our goal will be to train a generator network in a GAN setting, which can sample from a distribution with a similar covariance matrix.
#
# For reference, here's the sample covariance matrix, obtained when sampling from this distribution:

# %%
X_train = np.random.multivariate_normal(mean=np.array([0. for _ in range(N)]), cov=cov_mat, size=10000)

# re-cover matrix
cov_mat_recovered = np.cov(X_train.T)

plt.imshow(cov_mat_recovered)
plt.title('Sample cov matrix from multivariate Gaussian');
plt.colorbar();

# %% [markdown]
# Let's now have a look at the distribution of our (flattened) training set:

# %%
plt.hist(X_train.flatten(), bins=50)
plt.title('Histogram of (flattened) training set samples');

# %% [markdown]
# ## Define our Generator and Critic Networks
# Here we'll define some very simple nets.

# %%
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.hidden_part = nn.Sequential(
            nn.Linear(z_dim, 32),
            nn.LeakyReLU(0.1),
        )
        self.output = nn.Linear(32, N)

    def forward(self, x):
        x = self.hidden_part(x)
        x = self.output(x)
        return x

class Critic(nn.Module):
    def __init__(self):
        super(Critic, self).__init__()
        self.hidden_part = nn.Sequential(
            nn.Linear(N, 10),
            nn.LeakyReLU(0.1),
            nn.Linear(10, 1)
        )
        self.output = nn.Identity()

    def forward(self, x):
        x = self.hidden_part(x)
        x = self.output(x)
        return x
    
critic = Critic()
generator = Generator()

# %% [markdown]
# We didn't train our generator yet, so it's just generating noise. What does the sample covariance matrix look like?

# %%
def plot_generator_cov(generator, n=10000):
    """ Try the generator on a noise mini-batch and compute sample covariance matrix
    """
    z = torch.from_numpy(np.random.randn(n, z_dim)).float()
    samples = generator(z)
    cov_mat_est = np.cov(samples.detach().numpy().T)
    plt.imshow(cov_mat_est)
    plt.title('sample covariance matrix from generator network');
    plt.colorbar();
    
plot_generator_cov(generator)

# %% [markdown]
# ## Time for training!
# We'll use [WGAN](https://arxiv.org/abs/1701.07875). Here we'll define our own optimizers for the generator and the critic, in order to use a slightly lower learning rate than the default one.
#
# We'll train for 50 epochs.
#
# We set `folder=None` so that no folder is created where all results would be stored. Otherwise we could give a path like `folder="TrainedModels/GAN"`. All results (summary, images, loss functions, tensorboard information, models) would be saved in that folder. You can control what should be saved in the `fit` method. This folder will never overwrite an existing folder. If the path already exists a new path of the form `folder=path_{TimeStamp}` is created.

# %%
optimizer = {
    "Generator": torch.optim.Adam,
    "Adversary": torch.optim.Adam
}
optimizer_kwargs = {
    "Generator": {"lr": 0.0001, "betas": (0.5, 0.999)},
    "Adversary": {"lr": 0.0001, "betas": (0.5, 0.999)},
}

gan = WassersteinGAN(
    generator, critic, z_dim=z_dim, x_dim=N, 
    optim=optimizer, optim_kwargs=optimizer_kwargs, device="cpu", folder=None
)

# %% [markdown]
# The training happens in the next cell. You can interrupt it at any time without loosing the results.

# %%
gan.fit(X_train, epochs=25, print_every="1e", enable_tensorboard=False)
# Out:
# ------------------------------------------------------------
# EPOCH: 1
# ------------------------------------------------------------
# Step: 313 / 7825 (Epoch: 1 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.00967496633529663
# Adversary: -0.0005652075633406639
# Adversary_fake: 0.00967496633529663
# Adversary_real: -0.010805381461977959
# RealFakeRatio: -1.1168391704559326
#
#
# Time left: ~0.194 minutes (Steps remaining: 7512).
# ------------------------------------------------------------
# EPOCH: 2
# ------------------------------------------------------------
# Step: 626 / 7825 (Epoch: 2 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010222638957202435
# Adversary: -0.0006751939654350281
# Adversary_fake: 0.010222638957202435
# Adversary_real: -0.01157302688807249
# RealFakeRatio: -1.132097840309143
#
#
# Time left: ~0.18 minutes (Steps remaining: 7199).
# ------------------------------------------------------------
# EPOCH: 3
# ------------------------------------------------------------
# Step: 939 / 7825 (Epoch: 3 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010330352932214737
# Adversary: -0.0005536670796573162
# Adversary_fake: 0.010330352932214737
# Adversary_real: -0.01143768709152937
# RealFakeRatio: -1.1071922779083252
#
#
# Time left: ~0.179 minutes (Steps remaining: 6886).
# ------------------------------------------------------------
# EPOCH: 4
# ------------------------------------------------------------
# Step: 1252 / 7825 (Epoch: 4 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.01026285719126463
# Adversary: -0.0004863990470767021
# Adversary_fake: 0.01026285719126463
# Adversary_real: -0.011235655285418034
# RealFakeRatio: -1.0947881937026978
#
#
# Time left: ~0.168 minutes (Steps remaining: 6573).
# ------------------------------------------------------------
# EPOCH: 5
# ------------------------------------------------------------
# Step: 1565 / 7825 (Epoch: 5 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.009674458764493465
# Adversary: -0.0010211877524852753
# Adversary_fake: 0.009674458764493465
# Adversary_real: -0.011716834269464016
# RealFakeRatio: -1.21110999584198
#
#
# Time left: ~0.16 minutes (Steps remaining: 6260).
# ------------------------------------------------------------
# EPOCH: 6
# ------------------------------------------------------------
# Step: 1878 / 7825 (Epoch: 6 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010118141770362854
# Adversary: -0.001417325809597969
# Adversary_fake: 0.010118141770362854
# Adversary_real: -0.012952793389558792
# RealFakeRatio: -1.2801553010940552
#
#
# Time left: ~0.151 minutes (Steps remaining: 5947).
# ------------------------------------------------------------
# EPOCH: 7
# ------------------------------------------------------------
# Step: 2191 / 7825 (Epoch: 7 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010349147953093052
# Adversary: -0.0013922019861638546
# Adversary_fake: 0.010349147953093052
# Adversary_real: -0.013133551925420761
# RealFakeRatio: -1.269046664237976
#
#
# Time left: ~0.143 minutes (Steps remaining: 5634).
# ------------------------------------------------------------
# EPOCH: 8
# ------------------------------------------------------------
# Step: 2504 / 7825 (Epoch: 8 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.011297779157757759
# Adversary: -0.0008541313000023365
# Adversary_fake: 0.011297779157757759
# Adversary_real: -0.013006041757762432
# RealFakeRatio: -1.1512033939361572
#
#
# Time left: ~0.134 minutes (Steps remaining: 5321).
# ------------------------------------------------------------
# EPOCH: 9
# ------------------------------------------------------------
# Step: 2817 / 7825 (Epoch: 9 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.011413519270718098
# Adversary: -0.00046407105401158333
# Adversary_fake: 0.011413519270718098
# Adversary_real: -0.012341661378741264
# RealFakeRatio: -1.0813195705413818
#
#
# Time left: ~0.126 minutes (Steps remaining: 5008).
# ------------------------------------------------------------
# EPOCH: 10
# ------------------------------------------------------------
# Step: 3130 / 7825 (Epoch: 10 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.00998910702764988
# Adversary: -5.157897248864174e-05
# Adversary_fake: 0.00998910702764988
# Adversary_real: -0.010092264972627163
# RealFakeRatio: -1.0103271007537842
#
#
# Time left: ~0.119 minutes (Steps remaining: 4695).
# ------------------------------------------------------------
# EPOCH: 11
# ------------------------------------------------------------
# Step: 3443 / 7825 (Epoch: 11 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010141927748918533
# Adversary: -0.0001487433910369873
# Adversary_fake: 0.010141927748918533
# Adversary_real: -0.010439414530992508
# RealFakeRatio: -1.0293323993682861
#
#
# Time left: ~0.11 minutes (Steps remaining: 4382).
# ------------------------------------------------------------
# EPOCH: 12
# ------------------------------------------------------------
# Step: 3756 / 7825 (Epoch: 12 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010231559164822102
# Adversary: -0.00023420201614499092
# Adversary_fake: 0.010231559164822102
# Adversary_real: -0.010699963197112083
# RealFakeRatio: -1.0457803010940552
#
#
# Time left: ~0.102 minutes (Steps remaining: 4069).
# ------------------------------------------------------------
# EPOCH: 13
# ------------------------------------------------------------
# Step: 4069 / 7825 (Epoch: 13 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010883772745728493
# Adversary: -0.00016916915774345398
# Adversary_fake: 0.010883772745728493
# Adversary_real: -0.0112221110612154
# RealFakeRatio: -1.0310864448547363
#
#
# Time left: ~0.094 minutes (Steps remaining: 3756).
# ------------------------------------------------------------
# EPOCH: 14
# ------------------------------------------------------------
# Step: 4382 / 7825 (Epoch: 14 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.01027429848909378
# Adversary: -0.00040369946509599686
# Adversary_fake: 0.01027429848909378
# Adversary_real: -0.011081697419285774
# RealFakeRatio: -1.0785843133926392
#
#
# Time left: ~0.086 minutes (Steps remaining: 3443).
# ------------------------------------------------------------
# EPOCH: 15
# ------------------------------------------------------------
# Step: 4695 / 7825 (Epoch: 15 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010344555601477623
# Adversary: -0.00028552673757076263
# Adversary_fake: 0.010344555601477623
# Adversary_real: -0.010915609076619148
# RealFakeRatio: -1.0552033185958862
#
#
# Time left: ~0.078 minutes (Steps remaining: 3130).
# ------------------------------------------------------------
# EPOCH: 16
# ------------------------------------------------------------
# Step: 5008 / 7825 (Epoch: 16 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010237198323011398
# Adversary: -0.0004408750683069229
# Adversary_fake: 0.010237198323011398
# Adversary_real: -0.011118948459625244
# RealFakeRatio: -1.0861319303512573
#
#
# Time left: ~0.07 minutes (Steps remaining: 2817).
# ------------------------------------------------------------
# EPOCH: 17
# ------------------------------------------------------------
# Step: 5321 / 7825 (Epoch: 17 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.01032827515155077
# Adversary: -0.0002580382861196995
# Adversary_fake: 0.01032827515155077
# Adversary_real: -0.010844351723790169
# RealFakeRatio: -1.0499674081802368
#
#
# Time left: ~0.062 minutes (Steps remaining: 2504).
# ------------------------------------------------------------
# EPOCH: 18
# ------------------------------------------------------------
# Step: 5634 / 7825 (Epoch: 18 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010308468714356422
# Adversary: -0.0003020474687218666
# Adversary_fake: 0.010308468714356422
# Adversary_real: -0.010912563651800156
# RealFakeRatio: -1.0586018562316895
#
#
# Time left: ~0.054 minutes (Steps remaining: 2191).
# ------------------------------------------------------------
# EPOCH: 19
# ------------------------------------------------------------
# Step: 5947 / 7825 (Epoch: 19 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010356019251048565
# Adversary: -0.0003620763309299946
# Adversary_fake: 0.010356019251048565
# Adversary_real: -0.011080171912908554
# RealFakeRatio: -1.0699257850646973
#
#
# Time left: ~0.046 minutes (Steps remaining: 1878).
# ------------------------------------------------------------
# EPOCH: 20
# ------------------------------------------------------------
# Step: 6260 / 7825 (Epoch: 20 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010680296458303928
# Adversary: -3.496324643492699e-05
# Adversary_fake: 0.010680296458303928
# Adversary_real: -0.010750222951173782
# RealFakeRatio: -1.006547212600708
#
#
# Time left: ~0.039 minutes (Steps remaining: 1565).
# ------------------------------------------------------------
# EPOCH: 21
# ------------------------------------------------------------
# Step: 6573 / 7825 (Epoch: 21 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010618733242154121
# Adversary: -0.0002921358682215214
# Adversary_fake: 0.010618733242154121
# Adversary_real: -0.011203004978597164
# RealFakeRatio: -1.0550227165222168
#
#
# Time left: ~0.031 minutes (Steps remaining: 1252).
# ------------------------------------------------------------
# EPOCH: 22
# ------------------------------------------------------------
# Step: 6886 / 7825 (Epoch: 22 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010287899523973465
# Adversary: -0.0001586955040693283
# Adversary_fake: 0.010287899523973465
# Adversary_real: -0.010605290532112122
# RealFakeRatio: -1.030850887298584
#
#
# Time left: ~0.023 minutes (Steps remaining: 939).
# ------------------------------------------------------------
# EPOCH: 23
# ------------------------------------------------------------
# Step: 7199 / 7825 (Epoch: 23 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010632975026965141
# Adversary: -0.00019089877605438232
# Adversary_fake: 0.010632975026965141
# Adversary_real: -0.011014772579073906
# RealFakeRatio: -1.0359069108963013
#
#
# Time left: ~0.016 minutes (Steps remaining: 626).
# ------------------------------------------------------------
# EPOCH: 24
# ------------------------------------------------------------
# Step: 7512 / 7825 (Epoch: 24 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010367256589233875
# Adversary: -0.00023835385218262672
# Adversary_fake: 0.010367256589233875
# Adversary_real: -0.010843964293599129
# RealFakeRatio: -1.045982003211975
#
#
# Time left: ~0.008 minutes (Steps remaining: 313).
# ------------------------------------------------------------
# EPOCH: 25
# ------------------------------------------------------------
# Step: 7825 / 7825 (Epoch: 25 / 25, Batch: 313 / 313)
# ------------------------------------------------------------
# Generator: -0.010428422130644321
# Adversary: -0.00016076397150754929
# Adversary_fake: 0.010428422130644321
# Adversary_real: -0.01074995007365942
# RealFakeRatio: -1.0308319330215454
#
#
# Time left: ~0.0 minutes (Steps remaining: 0).

# %% [markdown]
# ## Inspection of results
# By calling `get_training_results()` on any GAN object, you can get a list of samples (generated out of a fixed noise vector), as well as the lists of losses of the generator and discriminator:

# %%
samples, losses = gan.get_training_results()

# %% [markdown]
# First, let's check what's the distribution of (flattened) samples during the last iteration:

# %%
plt.hist(samples.flatten(), bins=50);

# %% [markdown]
# And now let's look at the losses of the generator and critic during training - we can just call `vegans.utils.plot_losses()`:

# %%
fig, axs = plot_losses(losses)

# %% [markdown]
# And the sample covariance matrix we obtain we drawing samples from our newly-trained generator:

# %%
plot_generator_cov(generator)

# %% [markdown]
# It looks very similar to the original matrix.
